# %% [markdown]
# <h2>❖ <u><b>Data Collection and summaries:</b></u></h2>
# <p>We collect ecommerce_sales_analysis.csv from kaggle.
# </p>

# %% [markdown]
# <p>As we have used python for data analysis , so now we import data using pandas library . Before we have kept our data in my drive , so we will load data from drive using pandas library pd.read_csv() .

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sn
import numpy as np

# %%
Ecom = pd.read_csv('/content/drive/My Drive/Dataset/ecommerce_sales_analysis.csv')

# %%
Ecom.head()
# Out:
#    product_id product_name        category   price  review_score  \
# 0           1    Product_1        Clothing  190.40           1.7
# 1           2    Product_2  Home & Kitchen  475.60           3.2
# 2           3    Product_3            Toys  367.34           4.5
# 3           4    Product_4            Toys  301.34           3.9
# 4           5    Product_5           Books   82.23           4.2
#
#    review_count  sales_month_1  sales_month_2  sales_month_3  sales_month_4  \
# 0           220            479            449             92            784
# 1           903             21            989            861            863
# 2           163            348            558            567            143
# 3           951            725            678             59             15
# 4           220            682            451            649            301
#
#    sales_month_5  sales_month_6  sales_month_7  sales_month_8  sales_month_9  \
# ...

# %% [markdown]
# Now we will see all information of data that help better understand to us .

# %%
Ecom.shape
# Out:
# (1000, 18)

# %%
list[Ecom.columns]
# Out:
# list[Index(['product_id', 'product_name', 'category', 'price', 'review_score',
#        'review_count', 'sales_month_1', 'sales_month_2', 'sales_month_3',
#        'sales_month_4', 'sales_month_5', 'sales_month_6', 'sales_month_7',
#        'sales_month_8', 'sales_month_9', 'sales_month_10', 'sales_month_11',
#        'sales_month_12'],
#       dtype='object')]

# %%
Ecom.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 18 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   product_id      1000 non-null   int64
#  1   product_name    1000 non-null   object
#  2   category        1000 non-null   object
#  3   price           1000 non-null   float64
#  4   review_score    1000 non-null   float64
#  5   review_count    1000 non-null   int64
#  6   sales_month_1   1000 non-null   int64
#  7   sales_month_2   1000 non-null   int64
#  8   sales_month_3   1000 non-null   int64
#  9   sales_month_4   1000 non-null   int64
#  10  sales_month_5   1000 non-null   int64
#  11  sales_month_6   1000 non-null   int64
#  12  sales_month_7   1000 non-null   int64
#  13  sales_month_8   1000 non-null   int64
#  14  sales_month_9   1000 non-null   int64
#  15  sales_month_10  1000 non-null   int64
#  16  sales_month_11  1000 non-null   int64
# ...

# %%
Ecom.describe()
# Out:
#         product_id        price  review_score  review_count  sales_month_1  \
# count  1000.000000  1000.000000   1000.000000   1000.000000    1000.000000
# mean    500.500000   247.677130      3.027600    526.506000     498.306000
# std     288.819436   144.607983      1.171243    282.269932     289.941478
# min       1.000000     7.290000      1.000000      1.000000       0.000000
# 25%     250.750000   121.810000      2.000000    283.750000     245.500000
# 50%     500.500000   250.920000      3.100000    543.000000     507.500000
# 75%     750.250000   373.435000      4.000000    772.000000     740.750000
# max    1000.000000   499.860000      5.000000    999.000000    1000.000000
#
#        sales_month_2  sales_month_3  sales_month_4  sales_month_5  \
# count    1000.000000    1000.000000    1000.000000    1000.000000
# mean      507.661000     506.739000     503.823000     487.194000
# std       285.992689     294.010873     286.645567     287.844324
# ...

# %% [markdown]
# <p>Now we identify the top selling products and categories across the year .</p>

# %%
Ecom["year"]=Ecom.iloc[:,6:].sum(axis=1)
Ecom.head()
# Out:
#    product_id product_name        category   price  review_score  \
# 0           1    Product_1        Clothing  190.40           1.7
# 1           2    Product_2  Home & Kitchen  475.60           3.2
# 2           3    Product_3            Toys  367.34           4.5
# 3           4    Product_4            Toys  301.34           3.9
# 4           5    Product_5           Books   82.23           4.2
#
#    review_count  sales_month_1  sales_month_2  sales_month_3  sales_month_4  \
# 0           220            479            449             92            784
# 1           903             21            989            861            863
# 2           163            348            558            567            143
# 3           951            725            678             59             15
# 4           220            682            451            649            301
#
#    sales_month_5  sales_month_6  sales_month_7  sales_month_8  sales_month_9  \
# ...

# %%
maximum=Ecom["year"].max()

# %%
Ecom[Ecom["year"]==maximum]["product_name"]#finding maximum selling products name in a year
# Out:
# 223    Product_224
# Name: product_name, dtype: object

# %%
#finding maximum selling categories name in a year
total_sale=Ecom.groupby("category")["year"].sum().reset_index()

# %%
total_sale
# Out:
#          category    year
# 0           Books  938229
# 1        Clothing  826536
# 2     Electronics  845120
# 3          Health  834414
# 4  Home & Kitchen  742141
# 5          Sports  916371
# 6            Toys  917101

# %%
maximum=total_sale["year"].max()

# %%
total_sale[total_sale["year"]==maximum]["category"]
# Out:
# 0    Books
# Name: category, dtype: object

# %% [markdown]
# <h2>❖ <u><b>Data preprocessing and cleaning :</b></u></h2>
# <p>As we seen before in info method that there are no null value in any columns and all the column's has correct data type. But to confirm null value we will call isnull method.</p>

# %%
Ecom.isnull().sum()
# Out:
# product_id        0
# product_name      0
# category          0
# price             0
# review_score      0
# review_count      0
# sales_month_1     0
# sales_month_2     0
# sales_month_3     0
# sales_month_4     0
# sales_month_5     0
# sales_month_6     0
# sales_month_7     0
# sales_month_8     0
# sales_month_9     0
# sales_month_10    0
# sales_month_11    0
# sales_month_12    0
# year              0
# dtype: int64

# %% [markdown]
# we have confirm that there are no null value in our dataset. So no need to us to clean dataset and call the columns data type has in its on data type, so, we don't need preprocess data . Now we can go to analysis.

# %% [markdown]
# <h2>❖ <u><b>Analysis  and  Visualization:</b></u></h2>
# <p>Now we will try to better data analysis using visualization through graph plotting.

# %% [markdown]
# <h3>Month-wise sales trends and detect seasonal pattern</h3>

# %%
mttls=list(Ecom.iloc[:,6:18].sum())

# %%
mname=list(Ecom.columns)[6:18]
mname
# Out:
# ['sales_month_1',
#  'sales_month_2',
#  'sales_month_3',
#  'sales_month_4',
#  'sales_month_5',
#  'sales_month_6',
#  'sales_month_7',
#  'sales_month_8',
#  'sales_month_9',
#  'sales_month_10',
#  'sales_month_11',
#  'sales_month_12']

# %%
# %matplotlib inline

# %%
plt.figure(figsize=(14,5))
plt.plot(mname,mttls,marker="*",markersize=12,markerfacecolor="red",color="green")
plt.title("seasonal sales pattern")
plt.xlabel("month name")
plt.ylabel("total sale")
plt.tight_layout()

# %% [markdown]
# <p>Now we will see top five categories products using pie chart</p>

# %%
t5cat=total_sale.sort_values("year",ascending=False).head()
t5cat
# Out:
#       category    year
# 0        Books  938229
# 6         Toys  917101
# 5       Sports  916371
# 2  Electronics  845120
# 3       Health  834414

# %%
t5cat.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 5 entries, 0 to 3
# Data columns (total 2 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   category  5 non-null      object
#  1   year      5 non-null      int64
# dtypes: int64(1), object(1)
# memory usage: 120.0+ bytes

# %%
plt.figure(figsize=(16,6))
plt.pie(t5cat["year"],labels=t5cat["category"],autopct="%1.1f%%")
plt.title("Top Five Categories Product")
plt.tight_layout()
plt.show()

# %% [markdown]
# <p>Now we will see relationship between customer review score and total product sale  per year.</p>

# %%
Ecom.columns
# Out:
# Index(['product_id', 'product_name', 'category', 'price', 'review_score',
#        'review_count', 'sales_month_1', 'sales_month_2', 'sales_month_3',
#        'sales_month_4', 'sales_month_5', 'sales_month_6', 'sales_month_7',
#        'sales_month_8', 'sales_month_9', 'sales_month_10', 'sales_month_11',
#        'sales_month_12', 'year'],
#       dtype='object')

# %%
plt.figure(figsize=(14,4))
plt.scatter(x=Ecom["review_score"],y=Ecom["year"],color="red")
plt.title("Relationship between Review Score and Total Product Sale Per Year")
plt.xlabel("review score")
plt.ylabel("total product sale per year")
plt.tight_layout()
plt.show()
